# %%
import pandas as pd
import numpy as np
from MDBS import *
from time import ctime
initialization()
initial_db()
initialize_order_db()
add_order(0,0,0,0,0);

# %%
print("Welcome")
reg_no = raw_input('Enter your Registration Number: ')

try:
    student_info = student_detail(reg_no)
except:
    print('Access Denied')
else:
    print('Hello '+student_info['Name'])
    print('Enter your choice as mentioned below')
    print('1. Order\n2. Account Details')
    choice = raw_input()

    if(choice == '1'):
        total_amount = 0.00
        ord_detail = view_order_db()
        prev_token = ord_detail.index.values.tolist()
        prev_token = prev_token[-1]
        items = []
        while(1):
            df = view_menu_db()
            print(df)
            item_id = raw_input('Enter the IDs of the item you want to order (seperate IDs using (,)): ')
            item_id_l = item_id.split(',')
            for o in item_id_l:
                items.append(df.loc[o]['Item'])
                total_amount = total_amount + order_amt(o)  
            more = raw_input('If you want to order more enter 0 else to confirm order enter 1: ')
            if(more == '0'):
                continue
            else:
                debit(reg_no,total_amount)
                add_order((prev_token+1),ctime(),reg_no,items,total_amount)
                print('You ordered: ')
                for i in items:
                    print(i)
                print('Your total amount is: '),(total_amount)
                print('Your token number: '),(prev_token+1)
                break
    elif(choice == '2'):
        print(student_detail(reg_no))
    else:
        print('Invalid Input')
# Out:
# Welcome
# Enter your Registration Number: 15BEC0260
# Hello Abhinav Kumar
# Enter your choice as mentioned below
# 1. Order
# 2. Account Details
# 1
#                                                 Item  Price
# Id
# A1                         Won Ton Soup with Chicken   5.00
# A2                                     Egg Drop Soup   4.50
# A3                                 Chicken Corn Soup   5.50
# A4                                 Hot and Sour Soup   5.00
# A5                        Egg Drop with Won Ton Soup   6.00
# A6                     Chicken Noodle (or Rice) Soup   5.00
# A7                             Garden Vegetable Soup   5.00
# A8                   Garden Vegetable Soup with Tofu   6.00
# A9                Chicken with Garden Vegetable Soup   6.40
# A10                     Hong Kong Style Won Ton Soup   8.50
# A11                  Young Chow Won Ton Soup (for 2)  11.95
# B1                                     Beef Egg Roll   3.00
# B2                                   Spring Roll (1)   3.00
# B3                            Vegetable Egg Roll (1)   2.25
# B4               Fried Won Ton with Chicken Meat (6)   6.25
# B5                                 Chicken Toast (4)   6.25
# B6        Fried Silky Tofu with Special Garlic Sauce   5.95
# B7                                  Scallion Pancake   5.75
# B8      Steamed (or Pan Fried) Chicken Dumplings (6)   7.95
# B9    Steamed (or Pan Fried) Vegetable Dumplings (6)   7.95
# B10                        Szechuan Soft Won Ton (8)   8.55
# B11                Chicken in Soothing Lettuce Wraps   8.90
# B12                                Teriyaki Beef (6)   7.95
# B13                           Fried Chicken Wing (6)   4.95
# B14                                 B.B.Q. Spareribs  13.95
# B15                            Pu Pu Platter (for 2)  18.95
# B16                               Cold Sesame Noodle   6.95
# SP1                    Chinese Scallion Pancake Wrap  18.95
# SP2                                 Teriyaki Chicken  18.95
# SP3                                Vegetable Tempura  15.95
# ...                                              ...    ...
# SR41                                   Sashimi Combo  18.00
# SR42                             Sushi Sashimi Combo  27.95
# SR43                              Sashimi Maki Combo  15.00
# L1                                    Orange Chicken   9.75
# L2                             General Tso's Chicken   9.75
# L3                                Chicken Cashewnuts   9.75
# L4                                  Kung Pao Chicken   9.75
# L5                               Chicken String Bean   9.75
# L6                                 Chicken Vegetable   9.75
# L7                              Chicken Garlic Sauce   9.75
# L8                Chicken Eggplant with Garlic Sauce   9.75
# L9                            Sweet and Sour Chicken   9.75
# L10                                 Chicken Broccoli   9.75
# L11                                    Hunan Chicken   9.75
# L12                                 Szechuan Chicken   9.75
# L13                                       Hunan Beef   9.75
# L14                               Beef with Broccoli   9.75
# L15                           Beef with Garlic Sauce   9.75
# L16                                 Beef String Bean   9.75
# L17                           Beef with Green Pepper   9.75
# L18                       Veal with Mixed Vegetables   9.75
# L19                                  Hunan Bean Curd   9.75
# L20                        Bean Curd with Vegetables   9.75
# L21                           Wok's Mixed Vegetables   9.75
# L22                             Szechuan String Bean   9.75
# L23                       Eggplant with Garlic Sauce   9.75
# L24                                  Chicken Mei Fan   9.75
# L26                                        Chow Mein   9.75
# L27                                          Lo Mein   9.75
# L28                                   Sesame Chicken   9.75
#
# [219 rows x 2 columns]
# Enter the IDs of the item you want to order (seperate IDs using (,)): L23,L4
# If you want to order more enter 0 else to confirm order enter 1: 1
# You ordered:
# Eggplant with Garlic Sauce
# Kung Pao Chicken
# Your total amount is:  19.5
# Your token number:  2
